# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xs = [1, 2, 3, 4, 5, 6] #x values
ys = [5, 4, 6, 5, 6, 7] #y values
plt.style.use("ggplot") #graph theme(style)
plt.plot(xs, ys) #first graph
plt.show()
plt.scatter(xs, ys) #second graph
plt.show()

# %%
xs = np.array([1, 2, 3, 4, 5, 6])
ys = np.array([5, 4, 6, 5, 6, 7])

def slope(xs, ys):
    #slope formula
    m = (((np.mean(xs)*np.mean(ys)) - np.mean(xs*ys)) / 
         ((np.mean(xs)**2) - np.mean(xs**2)))
    #intercept formula
    b = np.mean(ys) - m * np.mean(xs)
    return m,b

m, b = slope(xs, ys)

def squared_error(ys_orig,ys_line):
    return sum((ys_line - ys_orig) * (ys_line - ys_orig))
#R squared formula
def coefficient_of_determination(ys_orig,ys_line):
    y_mean_line = [np.mean(ys_orig) for y in ys_orig]
    squared_error_regr = squared_error(ys_orig, ys_line)
    squared_error_y_mean = squared_error(ys_orig, y_mean_line)
    return 1 - (squared_error_regr/squared_error_y_mean)

#regression line (mx + b)
regression_line = [(m*x)+b for x in xs]
#R squared
r_squared = coefficient_of_determination(ys,regression_line)

print("slope:", m)
print("intercept:", b)
print("r-squared:", r_squared )
plt.scatter(xs, ys)
plt.plot(xs, regression_line)
plt.show()
# Out:
# slope: 0.428571428571
# intercept: 4.0
# r-squared: 0.584415584416

# %%
from scipy import stats
m, b, r_value, p_value, std_err = stats.linregress(xs, ys) #sci py linear regression attribute 

print("slope:", m)
print("intercept:", b)
print("r-squared:", r_value**2)
# Out:
# slope: 0.428571428571
# intercept: 4.0
# r-squared: 0.584415584416
